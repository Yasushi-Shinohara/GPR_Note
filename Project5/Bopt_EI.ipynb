# %% [markdown]
# このノートブック/コードは佐々木翔氏に作成していただいたものをベースにしています。

# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
import numpy as np
from bayes_opt import BayesianOptimization
from bayes_opt import UtilityFunction
np.random.seed(seed=123)

# %%
#Define data, supervised data
#NOTE: Omitting the random value in the x2y for compatiblity with "BayesianOptimizaiont" library
def x2y(x):
    return 40.0*np.sin(x/1.0) - (0.3*(x+6.0))**2 - (0.2*(x-4.0))**2 - 1.0*np.abs(x+2.0) 
xmin = -20
xmax = 20
Nx = 1000
x = np.linspace(xmin, xmax, Nx).reshape(-1, 1)
#NOTE: By omitting the random value, simply use vecotrized call is avaialble
y = x2y(x)

plt.plot(x, y)
plt.show()

# %%
optimizer = BayesianOptimization(x2y, {'x': (xmin, xmax)}, random_state=123)
acqui_name = 'ei'
#acqui_name = 'poi'
#acqui_name = 'ucb'
kappa = 5.0
xi = 0.01
maxval_list = []
#
Nepoch = 16 #Number of optimization
nplotevery = Nepoch//16 #Plot the results in every this number

plt.figure(figsize=(16, 20))
optimizer.maximize(init_points=2, n_iter=0, kappa=kappa)
for i in range(Nepoch):
    optimizer.maximize(init_points=0, n_iter=1, kappa=kappa)
    x_sample = np.array([[res["params"]["x"]] for res in optimizer.res])
    y_sample = np.array([res["target"] for res in optimizer.res])

    optimizer._gp.fit(x_sample, y_sample)
    mean, std = optimizer._gp.predict(x, return_std=True)

    maxval = max(y_sample)           #Update maximum value up to now
    maxval_list.append(maxval)
    utility_function = UtilityFunction(kind=acqui_name, kappa=kappa, xi=xi)
    acqui = utility_function.utility(x, optimizer._gp, 0)
    if(i%nplotevery==0):
        plt.subplot(Nepoch//nplotevery+1,2,(i//nplotevery)*2+1)
        plt.title('epoch = '+str(i))
        plt.plot(x,np.array(mean))
        plt.plot(x,y,'k--')
        high_bound = mean+ 1.0*std
        lower_bound = mean- 1.0*std
        plt.fill_between(x[:,0],high_bound,lower_bound, alpha=0.5)
        plt.xlim(xmin,xmax)
        plt.ylim(1.2*np.amin(y),1.2*np.amax(y))
        plt.scatter(x_sample,y_sample)
        plt.subplot(Nepoch//nplotevery+1,2,(i//nplotevery)*2+2)
        plt.plot(x,acqui)
plt.savefig("bayes_"+str(acqui_name)+".png")
plt.show()

print("# Actual value of maximum is "+str(max(y)))
print("# Got value in the Bayesian_opt is "+str(maxval))
print("# Optimization is finished.")
plt.figure()
plt.plot(maxval_list)
plt.grid()
plt.show()
# Out:
# |   iter    |  target   |     x     |
# -------------------------------------
# |  1        |  12.26    |  7.859    |
# |  2        | -44.03    | -8.554    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  3        | -92.79    |  16.33    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  4        |  12.27    |  7.857    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  5        |  12.32    |  7.843    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  6        |  12.41    |  7.806    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  7        |  12.43    |  7.724    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  8        |  12.46    |  7.76     |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  9        |  12.46    |  7.759    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  10       |  12.46    |  7.76     |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  11       |  12.46    |  7.755    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  12       |  12.46    |  7.761    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  13       |  12.46    |  7.761    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  14       |  12.46    |  7.761    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  15       |  12.46    |  7.758    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  16       |  12.46    |  7.758    |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  17       |  12.46    |  7.76     |
# =====================================
# |   iter    |  target   |     x     |
# -------------------------------------
# |  18       |  12.46    |  7.759    |
# =====================================
# # Actual value of maximum is [34.12625438]
# # Got value in the Bayesian_opt is 12.457596039789596
# # Optimization is finished.
