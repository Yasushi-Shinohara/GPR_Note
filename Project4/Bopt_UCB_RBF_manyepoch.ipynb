# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
# %run ../common/SKL_GPR.py
# %run ../common/homemade_BO.py
np.random.seed(seed=123)

# %%
#Define data, supervised data
def x2y(x):
    f = 40.0*np.sin(x/1.0) - (0.3*(x+6.0))**2 - (0.2*(x-4.0))**2 - 1.0*np.abs(x+2.0) + np.random.normal(0,1,1)
    return f
#
xmin = -20
xmax = 20
Nx = 1000
x = np.linspace(xmin, xmax, Nx)
y = list(map(x2y,x)) #for python3
y = np.array(y)
plt.plot(x, y) #### plot true data
plt.show()

# %%
#Define GPR and Bayesian opt.
Noptimize = 100
#kernel = kernels.ConstantKernel() + kernels.ConstantKernel()*kernels.RBF()
kernel = kernels.RBF()
#kernel = kernels.ConstantKernel() + kernels.ConstantKernel()*kernels.Matern(nu=0.5)
#kernel = kernels.Matern(nu=0.5)
GPR = Gaussian_Process_Regression(kernel=kernel, alpha=1e-8, normalize_y=True, optimizer='fmin_l_bfgs_b', \
                                   copy_X_train=True, n_restarts_optimizer=Noptimize, random_state=123)
#
BO = Bayesian_opt()
#BO.acqui_name = 'EI'
#BO.acqui_name = 'PI'
BO.acqui_name = 'UCB'
print('# The choice of acquisition function: ',BO.acqui_name)
# Out:
# # The choice of acquisition function:  UCB

# %%
#Definition of array as the initial condition
x_sample_init = np.array([])
y_sample_init = np.array([])
Ninitial = 2
for i in range(Ninitial):
    x_point = np.random.uniform(xmin,xmax) #Initial point is randomely chosen
    x_sample_init = np.append(x_sample_init,x_point) 
    y_point = x2y(x_point) 
    y_sample_init = np.append(y_sample_init,y_point) 
#
Nepoch = 64 #Number of optimization
nplotevery = Nepoch//16 #Plot the results in every this number

mean, std, x_point, y_point, maxval_list = DO_BO(GPR, BO, x2y, x, x_sample_init, y_sample_init, Nepoch, nplotevery, answer_is_there=True)

plt.figure()
plt.plot(maxval_list)
plt.grid()
plt.show()
# Out:
# epoch =  0 , x_point, maxval = -20.0,  10.752429826046175
# epoch =  1 , x_point, maxval = 1.9819819819819813,  26.339501315902552
# epoch =  2 , x_point, maxval = -8.588588588588589,  26.339501315902552
# epoch =  3 , x_point, maxval = 20.0,  26.339501315902552
# epoch =  4 , x_point, maxval = -14.114114114114114,  26.339501315902552
# epoch =  5 , x_point, maxval = -3.343343343343342,  26.339501315902552
# epoch =  6 , x_point, maxval = 16.436436436436438,  26.339501315902552
# epoch =  7 , x_point, maxval = 4.784784784784783,  26.339501315902552
# epoch =  8 , x_point, maxval = -0.7007007007007005,  26.339501315902552
# epoch =  9 , x_point, maxval = 13.273273273273276,  26.339501315902552
# epoch =  10 , x_point, maxval = -16.996996996996998,  26.339501315902552
# epoch =  11 , x_point, maxval = -5.945945945945946,  26.339501315902552
# epoch =  12 , x_point, maxval = -11.31131131131131,  26.339501315902552
# epoch =  13 , x_point, maxval = 18.3983983983984,  26.339501315902552
# epoch =  14 , x_point, maxval = -18.35835835835836,  26.339501315902552
# epoch =  15 , x_point, maxval = -4.664664664664665,  35.96181503096964
# epoch =  16 , x_point, maxval = 1.0610610610610607,  35.96181503096964
# epoch =  17 , x_point, maxval = -10.47047047047047,  35.96181503096964
# epoch =  18 , x_point, maxval = -4.704704704704705,  35.96181503096964
# epoch =  19 , x_point, maxval = 11.631631631631631,  35.96181503096964
# epoch =  20 , x_point, maxval = 6.426426426426428,  35.96181503096964
# epoch =  21 , x_point, maxval = 14.794794794794797,  35.96181503096964
# epoch =  22 , x_point, maxval = -15.555555555555555,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([8.10674989e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.24806069e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  23 , x_point, maxval = 3.263263263263262,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([3.75764477e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 52, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  24 , x_point, maxval = -7.267267267267268,  35.96181503096964
# epoch =  25 , x_point, maxval = -12.632632632632632,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00011227]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  26 , x_point, maxval = 0.22022022022022014,  35.96181503096964
# epoch =  27 , x_point, maxval = 7.307307307307308,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.49053279e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 50, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([2.25325736e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 57, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-7.8558484e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  28 , x_point, maxval = -4.104104104104104,  35.96181503096964
# epoch =  29 , x_point, maxval = -1.9819819819819813,  35.96181503096964
# epoch =  30 , x_point, maxval = 10.67067067067067,  35.96181503096964
# epoch =  31 , x_point, maxval = -9.50950950950951,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-6.49565259e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 52, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  32 , x_point, maxval = 17.43743743743744,  35.96181503096964
# epoch =  33 , x_point, maxval = 14.034034034034036,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([7.06924116e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-7.35301967e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 61, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  34 , x_point, maxval = -19.15915915915916,  35.96181503096964
# epoch =  35 , x_point, maxval = -16.276276276276278,  35.96181503096964
# epoch =  36 , x_point, maxval = 19.31931931931932,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00028931]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 57, 'nit': 3, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  37 , x_point, maxval = 4.024024024024023,  35.96181503096964
# epoch =  38 , x_point, maxval = 8.82882882882883,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.37739407e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-8.39189743e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  39 , x_point, maxval = -11.951951951951951,  35.96181503096964
# epoch =  40 , x_point, maxval = -6.546546546546546,  35.96181503096964
# epoch =  41 , x_point, maxval = 12.472472472472475,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([7.30539826e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  42 , x_point, maxval = 1.541541541541541,  35.96181503096964
# epoch =  43 , x_point, maxval = -2.6626626626626617,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-3.49264483e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 63, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([0.00013645]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 50, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  44 , x_point, maxval = 15.595595595595597,  35.96181503096964
# epoch =  45 , x_point, maxval = 5.665665665665667,  35.96181503096964
# epoch =  46 , x_point, maxval = -17.67767767767768,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00018971]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 50, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  47 , x_point, maxval = -13.433433433433432,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00015104]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 61, 'nit': 7, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  48 , x_point, maxval = -4.504504504504505,  35.96181503096964
# epoch =  49 , x_point, maxval = -14.834834834834835,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00012222]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 51, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  50 , x_point, maxval = -7.947947947947949,  35.96181503096964
# epoch =  51 , x_point, maxval = 2.6626626626626617,  35.96181503096964
# epoch =  52 , x_point, maxval = -1.3013013013013008,  35.96181503096964
# epoch =  53 , x_point, maxval = -9.98998998998999,  35.96181503096964
# epoch =  54 , x_point, maxval = 10.19019019019019,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.0001346]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([8.25382191e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 65, 'nit': 7, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  55 , x_point, maxval = 6.866866866866868,  35.96181503096964
# epoch =  56 , x_point, maxval = 16.956956956956958,  35.96181503096964
# epoch =  57 , x_point, maxval = 0.6206206206206204,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([3.15330061e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 63, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.33787598e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  58 , x_point, maxval = 8.428428428428429,  35.96181503096964
# epoch =  59 , x_point, maxval = -10.91091091091091,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-3.38319537e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  60 , x_point, maxval = 13.673673673673676,  35.96181503096964
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00013133]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  61 , x_point, maxval = 18.87887887887888,  35.96181503096964
# epoch =  62 , x_point, maxval = -19.5995995995996,  35.96181503096964
# epoch =  63 , x_point, maxval = -3.7037037037037024,  35.96181503096964
# # Actual value of maximum is [34.65978763]
# # Got value in the Bayesian_opt is 35.96181503096964
# # Optimization is finished.
