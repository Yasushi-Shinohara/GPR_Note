# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
# %run ../common/SKL_GPR.py
# %run ../common/homemade_BO.py
np.random.seed(seed=123)

# %%
#Define data, supervised data
def x2y(x):
    f = 40.0*np.sin(x/1.0) - (0.3*(x+6.0))**2 - (0.2*(x-4.0))**2 - 1.0*np.abs(x+2.0) + np.random.normal(0,1,1)
    return f
#
xmin = -20
xmax = 20
Nx = 1000
x = np.linspace(xmin, xmax, Nx)
y = list(map(x2y,x)) #for python3
y = np.array(y)
plt.plot(x, y) #### plot true data
plt.show()

# %%
#Define GPR and Bayesian opt.
Noptimize = 100
#kernel = kernels.ConstantKernel() + kernels.ConstantKernel()*kernels.RBF()
kernel = kernels.RBF()
#kernel = kernels.ConstantKernel() + kernels.ConstantKernel()*kernels.Matern(nu=0.5)
#kernel = kernels.Matern(nu=0.5)
GPR = Gaussian_Process_Regression(kernel=kernel, alpha=1e-8, normalize_y=True, optimizer='fmin_l_bfgs_b', \
                                   copy_X_train=True, n_restarts_optimizer=Noptimize, random_state=123)
#
BO = Bayesian_opt()
#BO.acqui_name = 'EI'
BO.acqui_name = 'PI'
#O.acqui_name = 'UCB'
print('# The choice of acquisition function: ',BO.acqui_name)
# Out:
# # The choice of acquisition function:  PI

# %%
#Definition of array as the initial condition
x_sample_init = np.array([])
y_sample_init = np.array([])
Ninitial = 2
for i in range(Ninitial):
    x_point = np.random.uniform(xmin,xmax) #Initial point is randomely chosen
    x_sample_init = np.append(x_sample_init,x_point) 
    y_point = x2y(x_point) 
    y_sample_init = np.append(y_sample_init,y_point) 
#
Nepoch = 32 #Number of optimization
nplotevery = Nepoch//16 #Plot the results in every this number

mean, std, x_point, y_point, maxval_list = DO_BO(GPR, BO, x2y, x, x_sample_init, y_sample_init, Nepoch, nplotevery, answer_is_there=True)

plt.figure()
plt.plot(maxval_list)
plt.grid()
plt.show()
# Out:
# epoch =  0 , x_point, maxval = -20.0,  10.752429826046175
# epoch =  1 , x_point, maxval = 7.947947947947949,  11.295624028865637
# epoch =  2 , x_point, maxval = 7.787787787787789,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-6.01749484e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  3 , x_point, maxval = 7.6276276276276285,  12.904927214428332
# epoch =  4 , x_point, maxval = 7.7477477477477485,  12.904927214428332
# epoch =  5 , x_point, maxval = 7.827827827827829,  12.904927214428332
# epoch =  6 , x_point, maxval = 7.5875875875875884,  12.904927214428332
# epoch =  7 , x_point, maxval = -18.75875875875876,  12.904927214428332
# epoch =  8 , x_point, maxval = -17.55755755755756,  12.904927214428332
# epoch =  9 , x_point, maxval = -17.27727727727728,  12.904927214428332
# epoch =  10 , x_point, maxval = -17.037037037037038,  12.904927214428332
# epoch =  11 , x_point, maxval = -16.756756756756758,  12.904927214428332
# epoch =  12 , x_point, maxval = -16.436436436436438,  12.904927214428332
# epoch =  13 , x_point, maxval = -17.91791791791792,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.04385333e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  14 , x_point, maxval = -15.235235235235235,  12.904927214428332
# epoch =  15 , x_point, maxval = -14.034034034034034,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([2.71677864e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 61, 'nit': 6, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  16 , x_point, maxval = -15.955955955955956,  12.904927214428332
# epoch =  17 , x_point, maxval = -12.832832832832832,  12.904927214428332
# epoch =  18 , x_point, maxval = -18.23823823823824,  12.904927214428332
# epoch =  19 , x_point, maxval = -11.591591591591591,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.26087225e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 51, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  20 , x_point, maxval = -11.551551551551551,  12.904927214428332
# epoch =  21 , x_point, maxval = -11.511511511511511,  13.677008045575077
# epoch =  22 , x_point, maxval = -11.471471471471471,  14.238766839542247
# epoch =  23 , x_point, maxval = -11.751751751751751,  14.238766839542247
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.38931589e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 54, 'nit': 2, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  24 , x_point, maxval = -10.15015015015015,  14.238766839542247
# epoch =  25 , x_point, maxval = -10.03003003003003,  14.238766839542247
# epoch =  26 , x_point, maxval = -10.31031031031031,  14.238766839542247
# epoch =  27 , x_point, maxval = -10.27027027027027,  14.238766839542247
# epoch =  28 , x_point, maxval = -10.35035035035035,  14.238766839542247
# epoch =  29 , x_point, maxval = -8.70870870870871,  14.238766839542247
# epoch =  30 , x_point, maxval = -7.387387387387388,  14.238766839542247
# epoch =  31 , x_point, maxval = -6.106106106106106,  14.238766839542247
# # Actual value of maximum is [34.65978763]
# # Got value in the Bayesian_opt is 14.238766839542247
# # Optimization is finished.
