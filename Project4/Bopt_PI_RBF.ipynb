# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
# %run ../common/SKL_GPR.py
# %run ../common/homemade_BO.py
np.random.seed(seed=123)

# %%
#Define data, supervised data
def x2y(x):
    f = 40.0*np.sin(x/1.0) - (0.3*(x+6.0))**2 - (0.2*(x-4.0))**2 - 1.0*np.abs(x+2.0) + np.random.normal(0,1,1)
    return f
#
xmin = -20
xmax = 20
Nx = 1000
x = np.linspace(xmin, xmax, Nx)
y = list(map(x2y,x)) #for python3
y = np.array(y)
plt.plot(x, y) #### plot true data
plt.show()

# %%
#Define GPR and Bayesian opt.
Noptimize = 100
#kernel = kernels.ConstantKernel() + kernels.ConstantKernel()*kernels.RBF()
kernel = kernels.RBF()
#kernel = kernels.ConstantKernel() + kernels.ConstantKernel()*kernels.Matern(nu=0.5)
#kernel = kernels.Matern(nu=0.5)
GPR = Gaussian_Process_Regression(kernel=kernel, alpha=1e-10, normalize_y=True, optimizer='fmin_l_bfgs_b', \
                                   copy_X_train=True, n_restarts_optimizer=Noptimize, random_state=123)
#
BO = Bayesian_opt()
#BO.acqui_name = 'EI'
BO.acqui_name = 'PI'
#O.acqui_name = 'UCB'
print('# The choice of acquisition function: ',BO.acqui_name)
# Out:
# # The choice of acquisition function:  PI

# %%
#Definition of array as the initial condition
x_sample_init = np.array([])
y_sample_init = np.array([])
Ninitial = 2
for i in range(Ninitial):
    x_point = np.random.uniform(xmin,xmax) #Initial point is randomely chosen
    x_sample_init = np.append(x_sample_init,x_point) 
    y_point = x2y(x_point) 
    y_sample_init = np.append(y_sample_init,y_point) 
#
Nepoch = 32 #Number of optimization
nplotevery = Nepoch//16 #Plot the results in every this number

mean, std, x_point, y_point, maxval_list = DO_BO(GPR, BO, x2y, x, x_sample_init, y_sample_init, Nepoch, nplotevery, answer_is_there=True)

plt.figure()
plt.plot(maxval_list)
plt.grid()
plt.show()
# Out:
# epoch =  0 , x_point, maxval = -20.0,  10.752429826046175
# epoch =  1 , x_point, maxval = 7.947947947947949,  11.295624028865637
# epoch =  2 , x_point, maxval = 7.787787787787789,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# /home/shinohara/work/development/GPR_Note/common/homemade_BO.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   Z = (mean -  maxval - self.xi)/std
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.69458845e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 48, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([1.83235252e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 49, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  3 , x_point, maxval = 7.267267267267268,  12.904927214428332
# epoch =  4 , x_point, maxval = 7.6276276276276285,  12.904927214428332
# epoch =  5 , x_point, maxval = 7.067067067067068,  12.904927214428332
# epoch =  6 , x_point, maxval = 8.308308308308309,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([1.31808802e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  7 , x_point, maxval = -16.396396396396398,  12.904927214428332
# epoch =  8 , x_point, maxval = -12.872872872872872,  12.904927214428332
# epoch =  9 , x_point, maxval = -9.34934934934935,  12.904927214428332
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([1.43745779e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 54, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  10 , x_point, maxval = -5.865865865865866,  12.904927214428332
# epoch =  11 , x_point, maxval = -5.585585585585585,  19.085264257884102
# epoch =  12 , x_point, maxval = -5.545545545545545,  19.085264257884102
# epoch =  13 , x_point, maxval = -1.7417417417417411,  19.085264257884102
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.0001094]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 49, 'nit': 3, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  14 , x_point, maxval = 1.9019019019019012,  29.338715923824477
# epoch =  15 , x_point, maxval = 1.9419419419419413,  29.338715923824477
# epoch =  16 , x_point, maxval = 1.8218218218218212,  30.812236717060024
# epoch =  17 , x_point, maxval = 1.7817817817817811,  30.812236717060024
# epoch =  18 , x_point, maxval = 2.0220220220220213,  30.812236717060024
# epoch =  19 , x_point, maxval = -5.145145145145145,  30.812236717060024
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.81890742e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 55, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  20 , x_point, maxval = -5.105105105105105,  31.05166728448486
# epoch =  21 , x_point, maxval = -5.065065065065065,  31.860796987020702
# epoch =  22 , x_point, maxval = -5.025025025025025,  32.116368217521654
# epoch =  23 , x_point, maxval = -5.265265265265265,  32.116368217521654
# epoch =  24 , x_point, maxval = -6.066066066066066,  32.116368217521654
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.03817838e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 61, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  25 , x_point, maxval = 3.9439439439439425,  32.116368217521654
# epoch =  26 , x_point, maxval = 11.471471471471471,  32.116368217521654
# /home/shinohara/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.44487494e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56, 'nit': 4, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# epoch =  27 , x_point, maxval = -18.15815815815816,  32.116368217521654
# epoch =  28 , x_point, maxval = 13.273273273273276,  32.116368217521654
# epoch =  29 , x_point, maxval = 8.82882882882883,  32.116368217521654
# epoch =  30 , x_point, maxval = 15.035035035035037,  32.116368217521654
# epoch =  31 , x_point, maxval = 16.876876876876878,  32.116368217521654
# # Actual value of maximum is [34.65978763]
# # Got value in the Bayesian_opt is 32.116368217521654
# # Optimization is finished.
